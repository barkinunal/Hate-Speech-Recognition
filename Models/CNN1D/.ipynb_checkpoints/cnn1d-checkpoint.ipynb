# %%
from __future__ import print_function

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.datasets import imdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f4c8f5381e5f> in <module>
#       1 from __future__ import print_function
#       2
# ----> 3 from keras.preprocessing import sequence
#       4 from keras.models import Sequential
#       5 from keras.layers import Dense, Dropout, Activation
#
# ModuleNotFoundError: No module named 'keras'

# %%
data = pd.read_csv("fourth_label_cleared.csv", index_col=0)
data_df = pd.DataFrame(data)
data_df.columns = ["text", "label"]
data_df = data_df[data_df.label != 'spam']
data_df
# Out:
#                                                     text label
# 0       Horse face hoe stop playing before I show the...     1
# 1                             Alex Brosas another idiot      1
# 2       as Nancy Reagan would say   just say FUCKING ...     1
# 3       Not being homophobic here     but uhhhhhhhhhh...     1
# 4      I hate er chase because if the Bitch that work...     0
# ...                                                  ...   ...
# 29693  I stopped fucking with people who never fell t...     0
# 29694   She must of made a ugly bitch mad af  Tried t...     0
# 29695                               this fucked up bruh      0
# 29696   Oasis  cover of The Who   My Generation is fu...     0
# 29697   ion wish a heartbreak on anybody    not even ...     0
#
# [25769 rows x 2 columns]

# %%
vectorizer = CountVectorizer(min_df=0, lowercase=True, stop_words="english")
vectorizer.fit(data_df["text"])
vectorizer.vocabulary_
# Out:
# {'horse': 6623,
#  'face': 4751,
#  'hoe': 6501,
#  'stop': 13522,
#  'playing': 10648,
#  'world': 15695,
#  'yo': 15900,
#  'lil': 8170,
#  'ugly': 14793,
#  'ass': 723,
#  'alex': 330,
#  'brosas': 1861,
#  'idiot': 6802,
#  'nancy': 9441,
#  'reagan': 11420,
#  'say': 12213,
#  'just': 7541,
#  'fucking': 5389,
#  'like': 8164,
#  'homophobic': 6558,
#  'uhhhhhhhhhhh': 14798,
#  'think': 14201,
#  'fuck': 5369,
#  'trick': 14590,
#  'bitch': 1394,
#  'hate': 6259,
#  'er': 4537,
#  'chase': 2366,
#  'works': 15694,
#  'literally': 8227,
#  'evil': 4629,
#  'blowjobs': 1528,
#  'muslims': 9368,
#  'girls': 5723,
#  'gets': 5650,
#  'fucked': 5376,
#  'don': 4037,
#  'hmu': 6492,
#  'tired': 14338,
#  'ur': 14985,
#  'boring': 1652,
#  'sick': 12735,
#  'bitches': 1397,
#  'internet': 7084,
#  'brunette': 1887,
#  'babe': 902,
#  'beverly': 1292,
#  'riding': 11818,
#  'brutal': 1892,
#  'anal': 441,
#  'dildo': 3823,
#  'man': 8579,
#  'feminist': 4944,
#  'annoying': 501,
# ...

# %%
data1 = vectorizer.transform(data_df["text"]).toarray()

# %%
max_features = 5000
maxlen = 400
batch_size = 32
embedding_dims = 50
filters = 250
kernel_size = 3
hidden_dims = 250
epochs = 20

x_train, x_test, y_train, y_test = train_test_split(data1, data_df["label"], test_size=0.3)

print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
# Out:
# 18038 train sequences
# 7731 test sequences

# %%
print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Pad sequences (samples x time)
# x_train shape: (18038, 400)
# x_test shape: (7731, 400)

# %%
print('Build model...')
model = Sequential()
# Out:
# Build model...

# %%
model.add(Embedding(max_features, embedding_dims, input_length=maxlen))

model.add(Dropout(0.2))

# %%
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())

# %%
#SIGMOID RELU
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))

# %%
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
# Out:
# Train on 18038 samples, validate on 7731 samples
# Epoch 1/10
# 18038/18038 [==============================] - 123s 7ms/step - loss: 0.6742 - acc: 0.5963 - val_loss: 0.6677 - val_acc: 0.6074
# Epoch 2/10
# 18038/18038 [==============================] - 122s 7ms/step - loss: 0.6725 - acc: 0.5987 - val_loss: 0.6677 - val_acc: 0.6074
# Epoch 3/10
# 18038/18038 [==============================] - 122s 7ms/step - loss: 0.6722 - acc: 0.5988 - val_loss: 0.6678 - val_acc: 0.6074
# Epoch 4/10
# 18038/18038 [==============================] - 123s 7ms/step - loss: 0.6721 - acc: 0.5988 - val_loss: 0.6673 - val_acc: 0.6074
# Epoch 5/10
# 18038/18038 [==============================] - 123s 7ms/step - loss: 0.6721 - acc: 0.5986 - val_loss: 0.6669 - val_acc: 0.6074
# Epoch 6/10
# 18038/18038 [==============================] - 125s 7ms/step - loss: 0.6719 - acc: 0.5981 - val_loss: 0.6700 - val_acc: 0.6074
# Epoch 7/10
# ...

# %%
list_loss = [0.6742, 0.6725, 0.6722, 0.6721, 0.6721, 0.6719, 0.6720, 0.6719, 0.6720, 0.6719]
list_val_loss = [0.6677, 0.6677, 0.6678, 0.6673, 0.6669, 0.6700, 0.6682, 0.6693, 0.6691, 0.6685]

plt.plot(range(1,11), list_loss, color="b")
plt.title = "loss"
plt.xlabel = "range"
plt.ylabel = "loss values"
plt.show

plt.plot(range(1,11), list_val_loss, color="r")
plt.title = "val_loss"
plt.xlabel = "range"
plt.ylabel = "val_loss values"
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
epochs = 20 # EPOCH U EN OPTIMAL DEGERE GORE AYARLA

# %%
batch_size = 16
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
model = Sequential()
model.add(Embedding(max_features, embedding_dims, input_length=maxlen))
model.add(Dropout(0.2))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a74903e4dd1> in <module>
#       1 batch_size = 16
# ----> 2 x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
#       3 x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
#       4 model = Sequential()
#       5 model.add(Embedding(max_features, embedding_dims, input_length=maxlen))
#
# NameError: name 'sequence' is not defined

# %%
batch_size = 64
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
model = Sequential()
model.add(Embedding(max_features, embedding_dims, input_length=maxlen))
model.add(Dropout(0.2))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))

# %%
batch_size = 128
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
model = Sequential()
model.add(Embedding(max_features, embedding_dims, input_length=maxlen))
model.add(Dropout(0.2))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))

# %%
batch_size = 32 # EN IYI BATCH SIZE I BULUP BUNU DEGISTIR

# %%
# SIGMOID SIGMOID
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
model = Sequential()
model.add(Embedding(max_features, embedding_dims, input_length=maxlen))
model.add(Dropout(0.2))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('sigmoid'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))

# %%
# RELU RELU
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
model = Sequential()
model.add(Embedding(max_features, embedding_dims, input_length=maxlen))
model.add(Dropout(0.2))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('relu'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))

# %%
# TANH TANH
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
model = Sequential()
model.add(Embedding(max_features, embedding_dims, input_length=maxlen))
model.add(Dropout(0.2))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('tanh'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
